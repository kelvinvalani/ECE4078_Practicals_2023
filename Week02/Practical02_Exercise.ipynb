# %% [markdown]
# # Practical 02 Exercises

# %% [markdown]
# Note: Only the full trajectories will be displayed for Exercise 2 and 3

# %%
import numpy as np
from Practical02_Support.Renderer import *
from ece4078.Utility import StartMeshcat

# %%
vis = StartMeshcat()
# Out:
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7003/static/
# Meshcat URL if you are on local machine: <a href='http://127.0.0.1:7003/static/' target='_blank'>http://127.0.0.1:7003/static/</a>

# %% [markdown]
# # Coding exercises

# %% [markdown]
# # Exercise 1 (2pts): Determine the Location of the Front Wheel
#
# ![bicycle.png](https://i.postimg.cc/Z5NW5KCN/zIhei8A.png)
#
# Given the known 2D location of the centre of the rear wheel of the bicycle ($x$, $y$), determine the location of the centre of the front wheel ($x_f, y_f$) in the world frame.
#
# **Input**:
# - 1D array of shape 2x1 with the location of the rear wheel (rear_wheel_loc)
# - Orientation of the bicycle in radians (theta)
# - Bicycle length (length)
#
# **Output**:
# - 1D array of shape 2x1 with the location of the front wheel in the world frame (values should not be rounded)

# %%
def get_front_wheel_location(rear_wheel_loc=np.zeros(2), theta=0, length=0):
    front_wheel_loc = np.zeros(2)
    
    #: Add your code here  ------------------------------------------
    front_wheel_loc[0] = rear_wheel_loc[0] + length*np.cos(theta)
    front_wheel_loc[1] = rear_wheel_loc[1] + length*np.sin(theta)

    
    #ENDTODO -----------------------------------------------------------
    
    return front_wheel_loc

# %% [markdown]
# **Test your code**
#
# We have included a plot function ``display_bycicle_wheels`` to help you verify your answers. The function will display two frames, one to represent the rear wheel (red) and another to represent the front wheel (blue). Similarly, the function assumes that the steering angle $\delta$ is set to zero. Here is an example of how to use it:

# %%
rear_wheel = np.ones(2)*2
theta_angle = 0
front_wheel = get_front_wheel_location(rear_wheel_loc=rear_wheel, theta=theta_angle, length=0.5)

display_bicycle_wheels(rear_wheel, front_wheel, theta=theta_angle)

# %% [markdown]
# As visual test cases, we recommend to consider:
#
# - Where should be the front wheel if $\theta=0$?
# - Where should be the front wheel if $\theta=\frac{\pi}{2}$?

# %% [markdown]
# ### Exercise 2 (3pts): Extend Bicycle Model to Consider Velocity and Steering Angle Rate as Inputs
#
# In the example of the bicycle model, the bicycle took as inputs velocity $v$ and steering angle $\delta$.
#
# We now want to modify our model so that it receives velocity $v$ and steering rate $\varphi$ as control inputs instead. With this new control input, the bicycle state is now defined by its 2D position $(x,y)$,  orientation ($\theta$) and steering angle ($\delta$).
#
# You are tasked with deriving the revised model to handle the modified inputs and using the new model to compute the bicycle state for a total of $max\_T$ iterations using this new control input.
#
# Your code should input a constant input velocity and steering rate at each time step.
#
# **Input**:
# - 1D array with the initial bicycle state $[x, y, \theta, \delta]$
# - Bicycle length (length)
# - Maximum number of iterations (max_t)
# - Input velocity ($v_i$)
# - Input Steering_rate (phi)
#
#
# **Output**:
# - Array of bicycle states of length max_t. Column order must be $[x, y, \theta, \delta]$ (values should not be rounded)

# %%
def get_bicycle_trajectory(initial_state = np.array([1, 1, 0, 0]), length=1, max_t=100, v=0, phi=0):
    
    dt = 0.02
    states = np.zeros((max_t+1, initial_state.shape[0]))
    states[0,:] = initial_state
    
    
    #: Add your code here --------------------------------------------
    for iter in range(1, max_t+1):
        states[iter,:] = states[iter-1,:] + np.array([v*np.cos(states[iter-1,2])*dt, v*np.sin(states[iter-1,2])*dt, v*np.tan(states[iter-1,3])*dt/length, phi*dt])
        
    #ENDTODO -------------------------------------------------------------
    
    return states

# %% [markdown]
# **Test your code**
#
# We have included a rendering class to help you verify your answers. Here is an example of how to use it:

# %%
# Input parameters
initial_state=np.array([5, -5, np.pi/2, 0.7])

length=1
max_t=250
v_i=2.3
phi=0.1

trj = get_bicycle_trajectory(initial_state, length, max_t, v_i, phi)

vis.delete()
vis.Set2DView(scale = abs(initial_state[0]) + 1)
vis.mask_origin()
display_traj(vis, trj[:, :3], scale = 6)
display(vis.show_inline())
# Out:
# HBox(children=(Button(button_style='success', description='Play/Pause', layout=Layout(flex='1 1 0%', width='au…
# HTML(value='\n                <div style="height: 400px; width: 100%; overflow-x: auto; overflow-y: hidden; re…

# %% [markdown]
# As visual test cases, we recommend you to keep in mind that:
#
# - The bicycle should move in a straight line if $\delta=0$, and $\varphi=0$
# - The bicycle should move in a circular trajectory if $v \ne 0$, $\delta \ne 0$, and $\varphi=0$
# - The bicycle should move in a spiral trajectory if $v \ne 0$, and $\varphi\ne0$

# %% [markdown]
# ### Exercise 3 (2pts): Differential Drive Kinematic Model
#
# Let us consider a two-wheeled vehicle that has the rotation rate of the wheels as control inputs.
#
# ![diff_drive.png](https://i.postimg.cc/ryfKTG60/IuNNzVB.png)
#
# Given the kinematic constraints that relate the wheel rotation rates to the linear and angular velocity of the PenguiPi robot:
#
# $$
# v=\frac{rw_1 + rw_2}{2}
# $$
# $$
# \omega=\frac{rw_1 - rw_2}{l}
# $$
#
# compute the state, i.e., $[x, y, \theta]$ of the PenguiPi robot for a total of $T_{max}$ iterations using this new control input.
#
# **Input**:
# - 1D array with the initial robot state $[x, y, \theta]$
# - Wheels width (length, l)
# - Wheels radius (wheel_radius, r)
# - Maximum number of iterations (max_t)
# - Rotation rate of the right wheel (right_rate)
# - Rotation rate of the left wheel (left_rate)
#
# **Output**:
# - Array of robot states of lenght max_t. Column order must be $[x, y, \theta]$ (values should not be rounded)

# %%
def get_penguipi_trajectory(initial_state = np.array([1, 1, 0]), length=1, wheel_radius=0.1,
                            right_rate=0, left_rate=0, max_t=100):
    
    dt = 0.1
    states = np.zeros((max_t+1, initial_state.shape[0]))
    states[0, :] = initial_state

    v = wheel_radius*(right_rate+left_rate)/2
    omega = wheel_radius*(right_rate-left_rate)/length

    #: Add your code here --------------------------------------------
    for iter in range(1, max_t+1):
        if omega != 0:
            R =v/omega
            theta = states[iter-1,2] + dt*omega
            states[iter,:] = states[iter-1,:] + np.array([R*(-np.sin(states[iter-1,2])+np.sin(theta)),R*(np.cos(states[iter-1,2])-np.cos(theta)),dt*omega])
        else:
            theta = states[0, 2]
            states[iter,:] = states[iter-1,:] + np.array([dt*v*np.cos(theta),dt*v*np.sin(theta),0])


    #ENDTODO -------------------------------------------------------------
    return states

# %% [markdown]
# **Test your code**
#
# We have included a rendering class to help you verify your answers. Here is an example of how to use it:

# %%
# Input parameters
initial_state=np.array([1, 1, np.pi/6])
length=1
wheel_radius=0.2
right_rate=10
left_rate=5
max_t=100

trj = get_penguipi_trajectory(initial_state, length, wheel_radius, right_rate, left_rate, max_t)
vis.delete()
vis.Set2DView(scale = 4)
vis.mask_origin()
display_traj(vis, trj[:, :3], scale = 6)
display(vis.show_inline())
# Out:
# [[ 1.          1.          0.52359878]
#  [ 1.12594054  1.08136484  0.62359878]
#  [ 1.24312896  1.17489627  0.72359878]
#  [ 1.35039438  1.27965976  0.82359878]
#  [ 1.44666501  1.39460853  0.92359878]
#  [ 1.53097896  1.51859407  1.02359878]
#  [ 1.6024938   1.65037755  1.12359878]
#  [ 1.66049496  1.78864222  1.22359878]
#  [ 1.70440293  1.93200661  1.32359878]
#  [ 1.73377898  2.07903825  1.42359878]
#  [ 1.7483296   2.22826806  1.52359878]
#  [ 1.74790941  2.37820498  1.62359878]
#  [ 1.7325226   2.52735089  1.72359878]
#  [ 1.70232292  2.67421557  1.82359878]
#  [ 1.65761211  2.81733161  1.92359878]
#  [ 1.5988369   2.95526903  2.02359878]
#  [ 1.52658456  3.0866496   2.12359878]
#  [ 1.44157701  3.21016062  2.22359878]
#  [ 1.34466361  3.32456801  2.32359878]
#  [ 1.2368127   3.42872864  2.42359878]
#  [ 1.11910188  3.52160177  2.52359878]
#  [ 0.99270728  3.60225946  2.62359878]
#  [ 0.8588918   3.66989579  2.72359878]
#  [ 0.71899247  3.72383496  2.82359878]
#  [ 0.57440712  3.76353803  2.92359878]
#  [ 0.42658041  3.7886083   3.02359878]
#  [ 0.27698936  3.79879528  3.12359878]
#  [ 0.12712864  3.79399718  3.22359878]
#  [-0.02150438  3.77426194  3.32359878]
#  [-0.16742463  3.73978676  3.42359878]
#  [-0.3091741   3.69091609  3.52359878]
#  [-0.4453365   3.62813824  3.62359878]
#  [-0.57455132  3.55208045  3.72359878]
#  [-0.6955275   3.46350268  3.82359878]
#  [-0.80705627  3.36328997  3.92359878]
#  [-0.9080233   3.25244361  4.02359878]
#  [-0.99741973  3.13207113  4.12359878]
#  [-1.07435236  3.00337526  4.22359878]
#  [-1.1380525   2.86764189  4.32359878]
#  [-1.18788368  2.72622721  4.42359878]
#  [-1.223348    2.58054421  4.52359878]
#  [-1.24409111  2.43204848  4.62359878]
#  [-1.24990576  2.28222377  4.72359878]
#  [-1.24073384  2.13256705  4.82359878]
#  [-1.21666701  1.98457366  4.92359878]
#  [-1.17794572  1.83972229  5.02359878]
#  [-1.12495687  1.69946026  5.12359878]
#  [-1.05822991  1.56518901  5.22359878]
#  [-0.97843155  1.43825014  5.32359878]
#  [-0.8863591   1.31991197  5.42359878]
#  [-0.78293253  1.21135691  5.52359878]
#  [-0.66918524  1.1136696   5.62359878]
#  [-0.54625376  1.0278261   5.72359878]
#  [-0.41536637  0.95468414  5.82359878]
#  [-0.27783086  0.89497451  5.92359878]
#  [-0.13502144  0.84929382  6.02359878]
#  [ 0.01163499  0.8180985   6.12359878]
#  [ 0.16067308  0.80170023  6.22359878]
#  [ 0.3106037   0.80026288  6.32359878]
#  [ 0.45992879  0.81380078  6.42359878]
#  [ 0.60715634  0.84217869  6.52359878]
#  [ 0.75081529  0.88511306  6.62359878]
#  [ 0.88947027  0.9421749   6.72359878]
#  [ 1.02173587  1.01279406  6.82359878]
#  [ 1.14629055  1.09626495  6.92359878]
#  [ 1.26188978  1.19175356  7.02359878]
#  [ 1.36737855  1.29830578  7.12359878]
#  [ 1.46170284  1.41485699  7.22359878]
#  [ 1.54392019  1.54024265  7.32359878]
#  [ 1.61320912  1.67320994  7.42359878]
#  [ 1.66887732  1.8124303   7.52359878]
#  [ 1.71036856  1.95651268  7.62359878]
#  [ 1.73726828  2.10401746  7.72359878]
#  [ 1.74930771  2.25347083  7.82359878]
#  [ 1.74636656  2.40337949  7.92359878]
#  [ 1.7284742   2.5522456   8.02359878]
#  [ 1.69580942  2.69858175  8.12359878]
#  [ 1.64869859  2.84092579  8.22359878]
#  [ 1.58761242  2.97785547  8.32359878]
#  [ 1.51316127  3.10800263  8.42359878]
#  [ 1.42608904  3.23006688  8.52359878]
#  [ 1.32726571  3.3428286   8.62359878]
#  [ 1.21767869  3.44516111  8.72359878]
#  [ 1.09842296  3.53604194  8.82359878]
#  [ 0.97069006  3.61456304  8.92359878]
#  [ 0.83575626  3.67993984  9.02359878]
#  [ 0.69496978  3.73151913  9.12359878]
#  [ 0.54973731  3.76878555  9.22359878]
#  [ 0.40150996  3.79136673  9.32359878]
#  [ 0.25176878  3.79903706  9.42359878]
#  [ 0.10200992  3.7917199   9.52359878]
#  [-0.04627027  3.76948835  9.62359878]
#  [-0.19159022  3.73256455  9.72359878]
#  [-0.33249796  3.68131743  9.82359878]
#  [-0.46758556  3.61625903  9.92359878]
#  [-0.59550329  3.53803939 10.02359878]
#  [-0.71497302  3.44744007 10.12359878]
#  [-0.82480107  3.34536629 10.22359878]
#  [-0.92389006  3.23283794 10.32359878]
#  [-1.01124993  3.11097938 10.42359878]
#  [-1.0860078   2.98100816 10.52359878]]
# HBox(children=(Button(button_style='success', description='Play/Pause', layout=Layout(flex='1 1 0%', width='au…
# HTML(value='\n                <div style="height: 400px; width: 100%; overflow-x: auto; overflow-y: hidden; re…

# %% [markdown]
# As visual test cases, we recommend you to keep in mind that:
#
# - The PenguiPi robot should move in a straight line if $w_1=w_2$
# - The PenguiPi robot should turn to the left if $w_1>w_2$ (the right wheel moves faster than the left wheel)
# - The PenguiPi robot should turn to the right if $w_1<w_2$ (the left wheel moves faster than the right wheel)

# %% [markdown]
# # Grading
# Test cases for giving marks:
# - q1: Assess the `get_front_wheel_location` function (2 points)
# - q2: Assess the `get_bicycle_trajectory` function (3 points)
# - q3: Assess the `get_penguipi_trajectory` function (2 points)
#
# Hint: For question 2 and question 3, the body should have something like
# ```
# for i in range(max_t):
#     ...
#     states[i+1,:] = ...
# ```
# Because this is how the solution is constructed, the trajectory has `states[0, :] = initial_state` and the length of the trajectory should be equal to `max_t + 1`

# %%
import otter
grader = otter.Notebook(tests_dir = "Practical02_Support/tests")
grader.check_all()
# Out:
# q1 results: All test cases passed!
#
# q2 results:
#     q2 - 1 result:
#         Trying:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Expecting nothing
#         ok
#         Trying:
#             exec(_eval_timeout_print_str())
#         Expecting nothing
#         ok
#         Trying:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([5, -5, np.pi/4, 0.1]), max_t=200, v=2.3, phi=0.01)") # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         **********************************************************************
#         Line 4, in q2 0
#         Failed example:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([5, -5, np.pi/4, 0.1]), max_t=200, v=2.3, phi=0.01)") # doctest:+ELLIPSIS
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\kelvi\anaconda3\lib\doctest.py", line 1334, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 0[2]>", line 1, in <module>
#                 states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([5, -5, np.pi/4, 0.1]), max_t=200, v=2.3, phi=0.01)") # doctest:+ELLIPSIS
#               File "<string>", line 6, in eval_timeout_print
#             AttributeError: module 'signal' has no attribute 'alarm'
#         Trying:
#             pickle_name_list = (["q2_file1.pk"])
#         Expecting nothing
#         ok
#         Trying:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Expecting nothing
#         ok
#         Trying:
#             expected_result = False
#         Expecting nothing
#         ok
#         Trying:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Expecting nothing
#         **********************************************************************
#         Line 9, in q2 0
#         Failed example:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\kelvi\anaconda3\lib\doctest.py", line 1334, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 0[6]>", line 2, in <module>
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#             NameError: name 'states' is not defined
#         Trying:
#             expected_result
#         Expecting:
#             True
#         **********************************************************************
#         Line 12, in q2 0
#         Failed example:
#             expected_result
#         Expected:
#             True
#         Got:
#             False
#
#     q2 - 2 result:
#         Trying:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Expecting nothing
#         ok
#         Trying:
#             exec(_eval_timeout_print_str())
#         Expecting nothing
#         ok
#         Trying:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([1, 1, 0, 0.05]), max_t=200, v=1.3, phi=0.05)") # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         **********************************************************************
#         Line 4, in q2 1
#         Failed example:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([1, 1, 0, 0.05]), max_t=200, v=1.3, phi=0.05)") # doctest:+ELLIPSIS
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\kelvi\anaconda3\lib\doctest.py", line 1334, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 1[2]>", line 1, in <module>
#                 states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([1, 1, 0, 0.05]), max_t=200, v=1.3, phi=0.05)") # doctest:+ELLIPSIS
#               File "<string>", line 6, in eval_timeout_print
#             AttributeError: module 'signal' has no attribute 'alarm'
#         Trying:
#             pickle_name_list = (["q2_file2.pk"])
#         Expecting nothing
#         ok
#         Trying:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Expecting nothing
#         ok
#         Trying:
#             expected_result = False
#         Expecting nothing
#         ok
#         Trying:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Expecting nothing
#         **********************************************************************
#         Line 9, in q2 1
#         Failed example:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\kelvi\anaconda3\lib\doctest.py", line 1334, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 1[6]>", line 2, in <module>
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#             NameError: name 'states' is not defined
#         Trying:
#             expected_result
#         Expecting:
#             True
#         **********************************************************************
#         Line 12, in q2 1
#         Failed example:
#             expected_result
#         Expected:
#             True
#         Got:
#             False
#
#     q2 - 3 result:
#         Trying:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Expecting nothing
#         ok
#         Trying:
#             exec(_eval_timeout_print_str())
#         Expecting nothing
#         ok
#         Trying:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([5, -5, np.pi/4, 0.1]), max_t=200, v=0, phi=0.01)") # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         **********************************************************************
#         Line 4, in q2 2
#         Failed example:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([5, -5, np.pi/4, 0.1]), max_t=200, v=0, phi=0.01)") # doctest:+ELLIPSIS
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\kelvi\anaconda3\lib\doctest.py", line 1334, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 2[2]>", line 1, in <module>
#                 states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([5, -5, np.pi/4, 0.1]), max_t=200, v=0, phi=0.01)") # doctest:+ELLIPSIS
#               File "<string>", line 6, in eval_timeout_print
#             AttributeError: module 'signal' has no attribute 'alarm'
#         Trying:
#             pickle_name_list = (["q2_file3.pk"])
#         Expecting nothing
#         ok
#         Trying:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Expecting nothing
#         ok
#         Trying:
#             expected_result = False
#         Expecting nothing
#         ok
#         Trying:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Expecting nothing
#         **********************************************************************
#         Line 9, in q2 2
#         Failed example:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\kelvi\anaconda3\lib\doctest.py", line 1334, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 2[6]>", line 2, in <module>
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#             NameError: name 'states' is not defined
#         Trying:
#             expected_result
#         Expecting:
#             True
#         **********************************************************************
#         Line 12, in q2 2
#         Failed example:
#             expected_result
#         Expected:
#             True
#         Got:
#             False
#
#     q2 - 4 result:
#         Trying:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Expecting nothing
#         ok
#         Trying:
#             exec(_eval_timeout_print_str())
#         Expecting nothing
#         ok
#         Trying:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([1, 1, 0, 0.05]), max_t=200, v=0, phi=0.05)") # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         **********************************************************************
#         Line 4, in q2 3
#         Failed example:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([1, 1, 0, 0.05]), max_t=200, v=0, phi=0.05)") # doctest:+ELLIPSIS
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\kelvi\anaconda3\lib\doctest.py", line 1334, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 3[2]>", line 1, in <module>
#                 states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([1, 1, 0, 0.05]), max_t=200, v=0, phi=0.05)") # doctest:+ELLIPSIS
#               File "<string>", line 6, in eval_timeout_print
#             AttributeError: module 'signal' has no attribute 'alarm'
#         Trying:
#             pickle_name_list = (["q2_file4.pk"])
#         Expecting nothing
#         ok
#         Trying:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Expecting nothing
#         ok
#         Trying:
#             expected_result = False
#         Expecting nothing
#         ok
#         Trying:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Expecting nothing
#         **********************************************************************
#         Line 9, in q2 3
#         Failed example:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\kelvi\anaconda3\lib\doctest.py", line 1334, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 3[6]>", line 2, in <module>
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#             NameError: name 'states' is not defined
#         Trying:
#             expected_result
#         Expecting:
#             True
#         **********************************************************************
#         Line 12, in q2 3
#         Failed example:
#             expected_result
#         Expected:
#             True
#         Got:
#             False
#
#     q2 - 5 result:
#         Trying:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Expecting nothing
#         ok
#         Trying:
#             exec(_eval_timeout_print_str())
#         Expecting nothing
#         ok
#         Trying:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([1, 1, 0, 0]), max_t=200, v=0, phi=0)") # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         **********************************************************************
#         Line 4, in q2 4
#         Failed example:
#             states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([1, 1, 0, 0]), max_t=200, v=0, phi=0)") # doctest:+ELLIPSIS
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\kelvi\anaconda3\lib\doctest.py", line 1334, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 4[2]>", line 1, in <module>
#                 states = eval_timeout_print("get_bicycle_trajectory(initial_state=np.array([1, 1, 0, 0]), max_t=200, v=0, phi=0)") # doctest:+ELLIPSIS
#               File "<string>", line 6, in eval_timeout_print
#             AttributeError: module 'signal' has no attribute 'alarm'
#         Trying:
#             pickle_name_list = (["q2_file5.pk"])
#         Expecting nothing
#         ok
#         Trying:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Expecting nothing
#         ok
#         Trying:
#             expected_result = False
#         Expecting nothing
#         ok
#         Trying:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Expecting nothing
#         **********************************************************************
#         Line 9, in q2 4
#         Failed example:
#             for my_pickle in pickle_list:
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                 expected_result = expected_result or result
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\kelvi\anaconda3\lib\doctest.py", line 1334, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q2 4[6]>", line 2, in <module>
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#             NameError: name 'states' is not defined
#         Trying:
#             expected_result
#         Expecting:
#             True
#         **********************************************************************
#         Line 12, in q2 4
#         Failed example:
#             expected_result
#         Expected:
#             True
#         Got:
#             False
#
# q3 results:
#     q3 - 1 result:
#         Trying:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Expecting nothing
#         ok
#         Trying:
#             exec(_eval_timeout_print_str())
#         Expecting nothing
#         ok
#         Trying:
#             states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([0, 0, np.pi/2]), max_t=200, right_rate=10, left_rate=10)") # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         **********************************************************************
#         Line 4, in q3 0
#         Failed example:
#             states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([0, 0, np.pi/2]), max_t=200, right_rate=10, left_rate=10)") # doctest:+ELLIPSIS
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\kelvi\anaconda3\lib\doctest.py", line 1334, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 0[2]>", line 1, in <module>
#                 states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([0, 0, np.pi/2]), max_t=200, right_rate=10, left_rate=10)") # doctest:+ELLIPSIS
#               File "<string>", line 6, in eval_timeout_print
#             AttributeError: module 'signal' has no attribute 'alarm'
#         Trying:
#             pickle_name_list = (["q3_file1.pk"])
#         Expecting nothing
#         ok
#         Trying:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Expecting nothing
#         ok
#         Trying:
#             expected_result = False
#         Expecting nothing
#         ok
#         Trying:
#             for my_pickle in pickle_list:
#                result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                expected_result = expected_result or result
#         Expecting nothing
#         **********************************************************************
#         Line 9, in q3 0
#         Failed example:
#             for my_pickle in pickle_list:
#                result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                expected_result = expected_result or result
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\kelvi\anaconda3\lib\doctest.py", line 1334, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 0[6]>", line 2, in <module>
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#             NameError: name 'states' is not defined
#         Trying:
#             expected_result
#         Expecting:
#             True
#         **********************************************************************
#         Line 12, in q3 0
#         Failed example:
#             expected_result
#         Expected:
#             True
#         Got:
#             False
#
#     q3 - 2 result:
#         Trying:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Expecting nothing
#         ok
#         Trying:
#             exec(_eval_timeout_print_str())
#         Expecting nothing
#         ok
#         Trying:
#             states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([1, -1, np.pi/4]), max_t=200, right_rate=20, left_rate=10)") # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         **********************************************************************
#         Line 4, in q3 1
#         Failed example:
#             states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([1, -1, np.pi/4]), max_t=200, right_rate=20, left_rate=10)") # doctest:+ELLIPSIS
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\kelvi\anaconda3\lib\doctest.py", line 1334, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 1[2]>", line 1, in <module>
#                 states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([1, -1, np.pi/4]), max_t=200, right_rate=20, left_rate=10)") # doctest:+ELLIPSIS
#               File "<string>", line 6, in eval_timeout_print
#             AttributeError: module 'signal' has no attribute 'alarm'
#         Trying:
#             pickle_name_list = (["q3_file2.pk"])
#         Expecting nothing
#         ok
#         Trying:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Expecting nothing
#         ok
#         Trying:
#             expected_result = False
#         Expecting nothing
#         ok
#         Trying:
#             for my_pickle in pickle_list:
#                result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                expected_result = expected_result or result
#         Expecting nothing
#         **********************************************************************
#         Line 9, in q3 1
#         Failed example:
#             for my_pickle in pickle_list:
#                result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                expected_result = expected_result or result
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\kelvi\anaconda3\lib\doctest.py", line 1334, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 1[6]>", line 2, in <module>
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#             NameError: name 'states' is not defined
#         Trying:
#             expected_result
#         Expecting:
#             True
#         **********************************************************************
#         Line 12, in q3 1
#         Failed example:
#             expected_result
#         Expected:
#             True
#         Got:
#             False
#
#     q3 - 3 result:
#         Trying:
#             from ece4078.Utility import _eval_timeout_print_str, enumerate_pickle
#         Expecting nothing
#         ok
#         Trying:
#             exec(_eval_timeout_print_str())
#         Expecting nothing
#         ok
#         Trying:
#             states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([1, -1, np.pi/4]), max_t=200, right_rate=10, left_rate=20)") # doctest:+ELLIPSIS
#         Expecting:
#             skip ...
#         **********************************************************************
#         Line 4, in q3 2
#         Failed example:
#             states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([1, -1, np.pi/4]), max_t=200, right_rate=10, left_rate=20)") # doctest:+ELLIPSIS
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\kelvi\anaconda3\lib\doctest.py", line 1334, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 2[2]>", line 1, in <module>
#                 states = eval_timeout_print("get_penguipi_trajectory(initial_state=np.array([1, -1, np.pi/4]), max_t=200, right_rate=10, left_rate=20)") # doctest:+ELLIPSIS
#               File "<string>", line 6, in eval_timeout_print
#             AttributeError: module 'signal' has no attribute 'alarm'
#         Trying:
#             pickle_name_list = (["q3_file3.pk"])
#         Expecting nothing
#         ok
#         Trying:
#             pickle_list = enumerate_pickle(pickle_name_list, path = "Practical02_Support/pickle/")
#         Expecting nothing
#         ok
#         Trying:
#             expected_result = False
#         Expecting nothing
#         ok
#         Trying:
#             for my_pickle in pickle_list:
#                result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                expected_result = expected_result or result
#         Expecting nothing
#         **********************************************************************
#         Line 9, in q3 2
#         Failed example:
#             for my_pickle in pickle_list:
#                result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#                expected_result = expected_result or result
#         Exception raised:
#             Traceback (most recent call last):
#               File "c:\Users\kelvi\anaconda3\lib\doctest.py", line 1334, in __run
#                 exec(compile(example.source, filename, "single",
#               File "<doctest q3 2[6]>", line 2, in <module>
#                 result = np.all(np.isclose(my_pickle[:, :], states[:, :]))
#             NameError: name 'states' is not defined
#         Trying:
#             expected_result
#         Expecting:
#             True
#         **********************************************************************
#         Line 12, in q3 2
#         Failed example:
#             expected_result
#         Expected:
#             True
#         Got:
#             False
